# %% [markdown]
# <a href="https://colab.research.google.com/github/DarrellCepeda128/EPPL-Are-de-un-triangulo-rectangulo/blob/main/Act_11_DF_%2B_codigo_Python_Cepeda_Darrell_0030.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Cepeda Darrell NL = 10 Fecha 25/Marzo/2026 NC = 2530805128**0030**
# ---
# # Calcular el area de un Triangulo rectangulo
# ---
# ![Area de un triangulo rectangulo](https://www.neurochispas.com/wp-content/uploads/2021/03/formula-del-area-de-un-triangulo-rectangulo.png)
# ---
# # Formula para calcular el area
# $A= B * H /2$
# # Datos de entrada
# * $B$ ? $H$ ?
# * $A$
# ---
# # Diagrama de flujo en LucidChart
# ![DF area triangulo rectangulo](https://raw.githubusercontent.com/DarrellCepeda128/EPPL-Are-de-un-triangulo-rectangulo/refs/heads/main/DF%20triangulo%20rectangulo....png)

# %%
# Calcula el area de triangulo rectangulo
# Variables B, H, A
# formula A= B*H/2
import math
B=float(input("Ingrese la base del triangulo: "))
H=float(input("Ingrese la altura del triangulo: "))
A=B*H/2
print("El area del triangulo es: ",A)
print("Cepeda Darrell NL = 10")
# Out:
# Ingrese la base del triangulo: 8
# Ingrese la altura del triangulo: 12
# El area del triangulo es:  48.0
# Cepeda Darrell NL = 10

# %% [markdown]
# # Relacion entre codigo y DF en Tldraw
# ![DF Completado](https://raw.githubusercontent.com/DarrellCepeda128/EPPL-Are-de-un-triangulo-rectangulo/refs/heads/main/DF%20Triangulo%20completado.PNG)
